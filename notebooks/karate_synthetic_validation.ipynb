# %% [markdown]
# # FGL heterogeneity benchmark proof of concept
#
# This notebook runs the self-contained validation workflow on the Karate Club graph and on synthetic cross-domain graph collections.

# %%
from validation.test_protocol_invariants import main as invariants_main
from validation.validate_karate import main as karate_main
from validation.validate_synthetic_domains import main as synthetic_main

# %%
invariants_main()

# %%
karate_main()

# %%
synthetic_main()
